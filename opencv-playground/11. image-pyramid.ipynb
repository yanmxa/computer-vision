# %%
from utils.im import *

# %%
import cv2 as cv

# %%
image = cv.imread("./images/imagenet/camels.jpg")
show(image)

# %%
# 高斯金字塔
image = cv.imread("./images/imagenet/camels.jpg")
for i in range(4):
    image = cv.pyrDown(image)
    print(image.shape)
    show(image)
# Out:
# (338, 450, 3)
# (169, 225, 3)
# (85, 113, 3)
# (43, 57, 3)

# %%
for i in range(4):
    image = cv.pyrUp(image)
    print(image.shape)
    show(image)
# Out:
# (86, 114, 3)
# (172, 228, 3)
# (344, 456, 3)
# (688, 912, 3)

# %%
# 拉普拉斯金字塔
image = cv.imread("./images/imagenet/camels.jpg")
image_down1 = cv.pyrDown(image)
image_down2 = cv.pyrDown(image_down1)
image_up = cv.pyrUp(image_down2)
laplacian = image_down1 - image_up
show(laplacian)

# %%
show(image_down1)
