# %% [markdown]
# # Pre-Trained ImageNet Models
#
# - LeNet
# - AlexNet
# - VGGNet(VGG16 and VGG19)
# - ResNet50
# - IncptionV3
# - Xception

# %% [markdown]
# - ImageNet dataset refers to ImageNet Large Scale Visual Recoginition Challenge
# - http://www.image-net.org/challenges/LSVRC
# - It is a dataset comprising of over 1.2 million training images separated into 1000 object classes
# - It is THE benchmark/standard used to test modern Deep Learning CNNs

# %% [markdown]
# ### Famous CNNs
# - To view all the pre-trained models shipped with Keras https://keras.io/applications
# ![image.png](attachment:image.png)
